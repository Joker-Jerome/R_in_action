# %%
R.Version()
# Out:
# $platform
# [1] "x86_64-apple-darwin15.6.0"
#
# $arch
# [1] "x86_64"
#
# $os
# [1] "darwin15.6.0"
#
# $system
# [1] "x86_64, darwin15.6.0"
#
# $status
# [1] ""
#
# $major
# [1] "3"
#
# $minor
# [1] "6.0"
#
# $year
# [1] "2019"
#
# $month
# [1] "04"
#
# $day
# [1] "26"
#
# $`svn rev`
# [1] "76424"
#
# $language
# [1] "R"
#
# $version.string
# [1] "R version 3.6.0 (2019-04-26)"
#
# $nickname
# [1] "Planting of a Tree"
